# %% [markdown]
# # Emudiaga Rukevwe Ericson Python Series-
# ## PyData 1.0

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
sns.set()
import sklearn as sk

# %% [markdown]
# ## 2. Load Data

# %%
loan = pd.read_csv('loans.csv')
loan.head()

# %%
loan.describe(include='all')
# Out:
#            loan_id  customer_id  issue_date    due_date principal_amount  \
# count     10.00000    10.000000          10          10               10
# unique         NaN          NaN           4           4                5
# top            NaN          NaN  2024-01-10  2024-07-01         ₦50000??
# freq           NaN          NaN           6           5                5
# mean    4005.50000  1010.800000         NaN         NaN              NaN
# std        3.02765     6.908931         NaN         NaN              NaN
# min     4001.00000  1001.000000         NaN         NaN              NaN
# 25%     4003.25000  1004.250000         NaN         NaN              NaN
# 50%     4005.50000  1011.500000         NaN         NaN              NaN
# 75%     4007.75000  1016.500000         NaN         NaN              NaN
# max     4010.00000  1019.000000         NaN         NaN              NaN
#
#        interest_rate  status
# count              7      10
# unique             3       4
# top              12%  repaid
# freq               4       5
# mean             NaN     NaN
# std              NaN     NaN
# min              NaN     NaN
# 25%              NaN     NaN
# 50%              NaN     NaN
# 75%              NaN     NaN
# max              NaN     NaN

# %%
loan.columns
# Out:
# Index(['loan_id', 'customer_id', 'issue_date', 'due_date', 'principal_amount',
#        'interest_rate', 'status'],
#       dtype='object')

# %%
loan.shape
# Out:
# (10, 7)

# %%
loan=loan.fillna('')
loan
# Out:
#    loan_id  customer_id  issue_date    due_date principal_amount  \
# 0     4001         1017  2023/09/15  2024/09/15         ₦50000??
# 1     4002         1014  2023-07-01  2024-07-01         ₦50000??
# 2     4003         1019  2024-01-10  2024-07-01         ₦50000??
# 3     4004         1019  2024-01-10  2024-07-01         ₦100,000
# 4     4005         1003          ??  2024-07-01          ₦75,000
# 5     4006         1009          ??  2024/12/31           ?90000
# 6     4007         1008  2024-01-10  2024/09/15          ₦120000
# 7     4008         1015  2024-01-10  2024-05-10         ₦50000??
# 8     4009         1003  2024-01-10  2024-05-10         ₦50000??
# 9     4010         1001  2024-01-10  2024-07-01           ?90000
#
#   interest_rate   status
# 0                 repaid
# 1           12%  pending
# 2           12%   active
# 3           12%   repaid
# 4                 repaid
# 5           10%   repaid
# 6           15%   active
# 7                default
# 8           15%   repaid
# 9           12%  pending

# %%
loan['principal_amount'] = (
    loan['principal_amount']
    .astype(str)
    .str.replace(r'[^0-9.]', '', regex=True)
    .astype(float)
)
loan
# Out:
#    loan_id  customer_id  issue_date    due_date  principal_amount  \
# 0     4001         1017  2023/09/15  2024/09/15           50000.0
# 1     4002         1014  2023-07-01  2024-07-01           50000.0
# 2     4003         1019  2024-01-10  2024-07-01           50000.0
# 3     4004         1019  2024-01-10  2024-07-01          100000.0
# 4     4005         1003          ??  2024-07-01           75000.0
# 5     4006         1009          ??  2024/12/31           90000.0
# 6     4007         1008  2024-01-10  2024/09/15          120000.0
# 7     4008         1015  2024-01-10  2024-05-10           50000.0
# 8     4009         1003  2024-01-10  2024-05-10           50000.0
# 9     4010         1001  2024-01-10  2024-07-01           90000.0
#
#   interest_rate   status
# 0                 repaid
# 1           12%  pending
# 2           12%   active
# 3           12%   repaid
# 4                 repaid
# 5           10%   repaid
# 6           15%   active
# 7                default
# 8           15%   repaid
# 9           12%  pending

# %%
loan['issue_date']=(
    loan['issue_date']
    .astype(str)
    .str.replace(r'[^0-9]','', regex=True)
)
loan
# Out:
#    loan_id  customer_id issue_date    due_date  principal_amount  \
# 0     4001         1017   20230915  2024/09/15           50000.0
# 1     4002         1014   20230701  2024-07-01           50000.0
# 2     4003         1019   20240110  2024-07-01           50000.0
# 3     4004         1019   20240110  2024-07-01          100000.0
# 4     4005         1003             2024-07-01           75000.0
# 5     4006         1009             2024/12/31           90000.0
# 6     4007         1008   20240110  2024/09/15          120000.0
# 7     4008         1015   20240110  2024-05-10           50000.0
# 8     4009         1003   20240110  2024-05-10           50000.0
# 9     4010         1001   20240110  2024-07-01           90000.0
#
#   interest_rate   status
# 0                 repaid
# 1           12%  pending
# 2           12%   active
# 3           12%   repaid
# 4                 repaid
# 5           10%   repaid
# 6           15%   active
# 7                default
# 8           15%   repaid
# 9           12%  pending

# %%
loan['due_date']=(
    loan['due_date']
    .astype(str)
    .str.replace(r'[^0-9]','', regex=True)
)
loan
# Out:
#    loan_id  customer_id issue_date  due_date  principal_amount interest_rate  \
# 0     4001         1017   20230915  20240915           50000.0
# 1     4002         1014   20230701  20240701           50000.0           12%
# 2     4003         1019   20240110  20240701           50000.0           12%
# 3     4004         1019   20240110  20240701          100000.0           12%
# 4     4005         1003             20240701           75000.0
# 5     4006         1009             20241231           90000.0           10%
# 6     4007         1008   20240110  20240915          120000.0           15%
# 7     4008         1015   20240110  20240510           50000.0
# 8     4009         1003   20240110  20240510           50000.0           15%
# 9     4010         1001   20240110  20240701           90000.0           12%
#
#     status
# 0   repaid
# 1  pending
# 2   active
# 3   repaid
# 4   repaid
# 5   repaid
# 6   active
# 7  default
# 8   repaid
# 9  pending

# %%
loan['issue_date'] = pd.to_datetime(loan['issue_date'], format='%Y%m%d')
loan['due_date'] = pd.to_datetime(loan['due_date'], format='%Y%m%d')
loan
# Out:
#    loan_id  customer_id issue_date   due_date  principal_amount interest_rate  \
# 0     4001         1017 2023-09-15 2024-09-15           50000.0
# 1     4002         1014 2023-07-01 2024-07-01           50000.0           12%
# 2     4003         1019 2024-01-10 2024-07-01           50000.0           12%
# 3     4004         1019 2024-01-10 2024-07-01          100000.0           12%
# 4     4005         1003        NaT 2024-07-01           75000.0
# 5     4006         1009        NaT 2024-12-31           90000.0           10%
# 6     4007         1008 2024-01-10 2024-09-15          120000.0           15%
# 7     4008         1015 2024-01-10 2024-05-10           50000.0
# 8     4009         1003 2024-01-10 2024-05-10           50000.0           15%
# 9     4010         1001 2024-01-10 2024-07-01           90000.0           12%
#
#     status
# 0   repaid
# 1  pending
# 2   active
# 3   repaid
# 4   repaid
# 5   repaid
# 6   active
# 7  default
# 8   repaid
# 9  pending

# %%
loan['interest_rate']=loan['interest_rate'].replace('',12)

loan
# Out:
#    loan_id  customer_id issue_date   due_date  principal_amount interest_rate  \
# 0     4001         1017 2023-09-15 2024-09-15           50000.0            12
# 1     4002         1014 2023-07-01 2024-07-01           50000.0           12%
# 2     4003         1019 2024-01-10 2024-07-01           50000.0           12%
# 3     4004         1019 2024-01-10 2024-07-01          100000.0           12%
# 4     4005         1003        NaT 2024-07-01           75000.0            12
# 5     4006         1009        NaT 2024-12-31           90000.0           10%
# 6     4007         1008 2024-01-10 2024-09-15          120000.0           15%
# 7     4008         1015 2024-01-10 2024-05-10           50000.0            12
# 8     4009         1003 2024-01-10 2024-05-10           50000.0           15%
# 9     4010         1001 2024-01-10 2024-07-01           90000.0           12%
#
#     status
# 0   repaid
# 1  pending
# 2   active
# 3   repaid
# 4   repaid
# 5   repaid
# 6   active
# 7  default
# 8   repaid
# 9  pending

# %%
loan['issue_date'] = loan['issue_date'].fillna(method='bfill')

loan
# Out:
# C:\Users\HELLO\AppData\Local\Temp\ipykernel_5912\1044377828.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   loan['issue_date'] = loan['issue_date'].fillna(method='bfill')
#    loan_id  customer_id issue_date   due_date  principal_amount interest_rate  \
# 0     4001         1017 2023-09-15 2024-09-15           50000.0            12
# 1     4002         1014 2023-07-01 2024-07-01           50000.0           12%
# 2     4003         1019 2024-01-10 2024-07-01           50000.0           12%
# 3     4004         1019 2024-01-10 2024-07-01          100000.0           12%
# 4     4005         1003 2024-01-10 2024-07-01           75000.0            12
# 5     4006         1009 2024-01-10 2024-12-31           90000.0           10%
# 6     4007         1008 2024-01-10 2024-09-15          120000.0           15%
# 7     4008         1015 2024-01-10 2024-05-10           50000.0            12
# 8     4009         1003 2024-01-10 2024-05-10           50000.0           15%
# 9     4010         1001 2024-01-10 2024-07-01           90000.0           12%
#
#     status
# 0   repaid
# 1  pending
# 2   active
# 3   repaid
# 4   repaid
# 5   repaid
# 6   active
# 7  default
# 8   repaid
# 9  pending

# %%
loan['interest_rate']=loan['interest_rate'].astype(str).str.replace('%','', regex=True).astype(float)
loan
# Out:
#    loan_id  customer_id issue_date   due_date  principal_amount  \
# 0     4001         1017 2023-09-15 2024-09-15           50000.0
# 1     4002         1014 2023-07-01 2024-07-01           50000.0
# 2     4003         1019 2024-01-10 2024-07-01           50000.0
# 3     4004         1019 2024-01-10 2024-07-01          100000.0
# 4     4005         1003 2024-01-10 2024-07-01           75000.0
# 5     4006         1009 2024-01-10 2024-12-31           90000.0
# 6     4007         1008 2024-01-10 2024-09-15          120000.0
# 7     4008         1015 2024-01-10 2024-05-10           50000.0
# 8     4009         1003 2024-01-10 2024-05-10           50000.0
# 9     4010         1001 2024-01-10 2024-07-01           90000.0
#
#    interest_rate   status
# 0           12.0   repaid
# 1           12.0  pending
# 2           12.0   active
# 3           12.0   repaid
# 4           12.0   repaid
# 5           10.0   repaid
# 6           15.0   active
# 7           12.0  default
# 8           15.0   repaid
# 9           12.0  pending

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   loan_id           10 non-null     int64
#  1   customer_id       10 non-null     int64
#  2   issue_date        10 non-null     datetime64[ns]
#  3   due_date          10 non-null     datetime64[ns]
#  4   principal_amount  10 non-null     float64
#  5   interest_rate     10 non-null     float64
#  6   status            10 non-null     object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(1)
# memory usage: 692.0+ bytes

# %%
loan.to_csv("clean_loan.csv")

# %%
accounts=pd.read_csv("accounts.csv")
accounts
# Out:
#     account_id  customer_id account_type   open_date  balance
# 0         2001         1017          CUR  2020-03-01   ₦70000
# 1         2002         1002          CUR  2021/04/12   40000@
# 2         2003         1012       saving  2022-06-09   40000@
# 3         2004         1003          CUR  2020-03-01   ₦70000
# 4         2005         1017      Savings  2020-03-01   ?30000
# 5         2006         1016         Loan  2021/04/12   40000@
# 6         2007         1020      Current  2019-11-15   40000@
# 7         2008         1003      Savings  2022-06-09   ₦70000
# 8         2009         1018      Current  2020-03-01   ₦70000
# 9         2010         1005       saving  2022-06-09  ₦12,000
# 10        2011         1016           SA  2022-06-09   ₦70000
# 11        2012         1014      Current  2019-11-15  ₦12,000
# 12        2013         1017      Current          ??   ₦50000
# 13        2014         1013      Savings  2022-06-09       ₦?
# 14        2015         1011       saving  2019-11-15   ₦70000
# 15        2016         1008       saving  2021/04/12   ₦50000
# 16        2017         1006       saving  2022-06-09   ₦70000
# 17        2018         1009         Loan  2022-06-09   ?30000
# 18        2019         1016       saving  2019-11-15  ₦12,000
# 19        2020         1010           SA  2019-11-15   40000@

# %%
accounts['balance']=accounts['balance'].astype(str).str.replace(r'[^0-9.]','',regex=True).replace('',np.nan).astype(float)
accounts
# Out:
#     account_id  customer_id account_type open_date  balance
# 0         2001         1017          CUR  20200301  70000.0
# 1         2002         1002          CUR  20210412  40000.0
# 2         2003         1012       saving  20220609  40000.0
# 3         2004         1003          CUR  20200301  70000.0
# 4         2005         1017      Savings  20200301  30000.0
# 5         2006         1016         Loan  20210412  40000.0
# 6         2007         1020      Current  20191115  40000.0
# 7         2008         1003      Savings  20220609  70000.0
# 8         2009         1018      Current  20200301  70000.0
# 9         2010         1005       saving  20220609  12000.0
# 10        2011         1016           SA  20220609  70000.0
# 11        2012         1014      Current  20191115  12000.0
# 12        2013         1017      Current       NaN  50000.0
# 13        2014         1013      Savings  20220609      NaN
# 14        2015         1011       saving  20191115  70000.0
# 15        2016         1008       saving  20210412  50000.0
# 16        2017         1006       saving  20220609  70000.0
# 17        2018         1009         Loan  20220609  30000.0
# 18        2019         1016       saving  20191115  12000.0
# 19        2020         1010           SA  20191115  40000.0

# %%
accounts['open_date']=accounts['open_date'].astype(str).str.replace(r'[^0-9.]','',regex=True).replace('',np.nan)
accounts
# Out:
#     account_id  customer_id account_type open_date  balance
# 0         2001         1017          CUR  20200301  70000.0
# 1         2002         1002          CUR  20210412  40000.0
# 2         2003         1012       saving  20220609  40000.0
# 3         2004         1003          CUR  20200301  70000.0
# 4         2005         1017      Savings  20200301  30000.0
# 5         2006         1016         Loan  20210412  40000.0
# 6         2007         1020      Current  20191115  40000.0
# 7         2008         1003      Savings  20220609  70000.0
# 8         2009         1018      Current  20200301  70000.0
# 9         2010         1005       saving  20220609  12000.0
# 10        2011         1016           SA  20220609  70000.0
# 11        2012         1014      Current  20191115  12000.0
# 12        2013         1017      Current       NaN  50000.0
# 13        2014         1013      Savings  20220609      NaN
# 14        2015         1011       saving  20191115  70000.0
# 15        2016         1008       saving  20210412  50000.0
# 16        2017         1006       saving  20220609  70000.0
# 17        2018         1009         Loan  20220609  30000.0
# 18        2019         1016       saving  20191115  12000.0
# 19        2020         1010           SA  20191115  40000.0

# %%
accounts['open_date']=pd.to_datetime(accounts['open_date'], format='%Y%m%d')
accounts['open_date']=accounts['open_date'].fillna(method="bfill")
accounts.head()
# Out:
# C:\Users\HELLO\AppData\Local\Temp\ipykernel_5912\443638161.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   accounts['open_date']=accounts['open_date'].fillna(method="bfill")
#    account_id  customer_id account_type  open_date  balance
# 0        2001         1017          CUR 2020-03-01  70000.0
# 1        2002         1002          CUR 2021-04-12  40000.0
# 2        2003         1012       saving 2022-06-09  40000.0
# 3        2004         1003          CUR 2020-03-01  70000.0
# 4        2005         1017      Savings 2020-03-01  30000.0

# %%
accounts['account_type']=accounts['account_type'].replace('current','c')
accounts['account_type']=accounts['account_type'].replace('Current','c')
accounts['account_type']=accounts['account_type'].replace('CUR','c')
accounts['account_type']=accounts['account_type'].replace('c','current')
accounts['account_type']=accounts['account_type'].replace('saving','s')
accounts['account_type']=accounts['account_type'].replace('Savings','s')
accounts['account_type']=accounts['account_type'].replace('SA','s')
accounts['account_type']=accounts['account_type'].replace('s','savings')
accounts
# Out:
#     account_id  customer_id account_type  open_date  balance
# 0         2001         1017      current 2020-03-01  70000.0
# 1         2002         1002      current 2021-04-12  40000.0
# 2         2003         1012      savings 2022-06-09  40000.0
# 3         2004         1003      current 2020-03-01  70000.0
# 4         2005         1017      savings 2020-03-01  30000.0
# 5         2006         1016         Loan 2021-04-12  40000.0
# 6         2007         1020      current 2019-11-15  40000.0
# 7         2008         1003      savings 2022-06-09  70000.0
# 8         2009         1018      current 2020-03-01  70000.0
# 9         2010         1005      savings 2022-06-09  12000.0
# 10        2011         1016      savings 2022-06-09  70000.0
# 11        2012         1014      current 2019-11-15  12000.0
# 12        2013         1017      current 2022-06-09  50000.0
# 13        2014         1013      savings 2022-06-09      NaN
# 14        2015         1011      savings 2019-11-15  70000.0
# 15        2016         1008      savings 2021-04-12  50000.0
# 16        2017         1006      savings 2022-06-09  70000.0
# 17        2018         1009         Loan 2022-06-09  30000.0
# 18        2019         1016      savings 2019-11-15  12000.0
# 19        2020         1010      savings 2019-11-15  40000.0

# %%
accounts['balance']=accounts['balance'].interpolate(method='linear')
accounts
# Out:
#     account_id  customer_id account_type  open_date  balance
# 0         2001         1017      current 2020-03-01  70000.0
# 1         2002         1002      current 2021-04-12  40000.0
# 2         2003         1012      savings 2022-06-09  40000.0
# 3         2004         1003      current 2020-03-01  70000.0
# 4         2005         1017      savings 2020-03-01  30000.0
# 5         2006         1016         Loan 2021-04-12  40000.0
# 6         2007         1020      current 2019-11-15  40000.0
# 7         2008         1003      savings 2022-06-09  70000.0
# 8         2009         1018      current 2020-03-01  70000.0
# 9         2010         1005      savings 2022-06-09  12000.0
# 10        2011         1016      savings 2022-06-09  70000.0
# 11        2012         1014      current 2019-11-15  12000.0
# 12        2013         1017      current 2022-06-09  50000.0
# 13        2014         1013      savings 2022-06-09  60000.0
# 14        2015         1011      savings 2019-11-15  70000.0
# 15        2016         1008      savings 2021-04-12  50000.0
# 16        2017         1006      savings 2022-06-09  70000.0
# 17        2018         1009         Loan 2022-06-09  30000.0
# 18        2019         1016      savings 2019-11-15  12000.0
# 19        2020         1010      savings 2019-11-15  40000.0

# %%
accounts.to_csv("accounts_clean.csv")

# %%
customers=pd.read_csv("customers.csv")
customers.head()
# Out:
#    customer_id first_name last_name   gender         dob   state  \
# 0         1001       John       Doe   Female  1989-04-12     Edo
# 1         1002       Mary    O?baje  Unknown  1995-12-02   Delta
# 2         1003    Danladi   Danladi   Female   1988-03-?   Lagos
# 3         1004      Grace       Ade        F  19??-10-11  Kaduna
# 4         1005     Chioma     Chuks   Female  19??-10-11   Enugu
#
#               email   join_date
# 0   user0@mail@mail  2020/03/01
# 1  user1@mail@gmail  2021/02/20
# 2   user2@mail@mail  2020/03/01
# 3  user3@mail@gmail  2021/02/20
# 4    user4@mail.com  2022-??-??

# %%
customers['first_name']=customers['first_name'].str.replace(r'[^A-Za-z]','', regex=True)
customers['last_name']=customers['last_name'].str.replace(r'[^A-Za-z]','', regex=True)
customers['gender']=customers['gender'].replace('F','Female')

customers
# Out:
#     customer_id first_name last_name   gender         dob   state  \
# 0          1001       John       Doe   Female  1989-04-12     Edo
# 1          1002       Mary     Obaje  Unknown  1995-12-02   Delta
# 2          1003    Danladi   Danladi   Female   1988-03-?   Lagos
# 3          1004      Grace       Ade   Female  19??-10-11  Kaduna
# 4          1005     Chioma     Chuks   Female  19??-10-11   Enugu
# 5          1006      Ahmed     Bello     Male  1994/11/23   Lagos
# 6          1007       Bola       Ade     Male  1995-12-02     Edo
# 7          1008       Ruth       Ebi     Male  1991-09-09   Delta
# 8          1009      Tunde     Taiwo  Unknown  1995-12-02   Enugu
# 9          1010      Ngozi      Okon  Unknown  1985-07-01   Enugu
# 10         1011      Emeka       Eze  Unknown   1988-03-?   Enugu
# 11         1012       Kate    Okafor   Female   1988-03-?   Abuja
# 12         1013       Femi   Adeyemi  Unknown   1988-03-?  Kaduna
# 13         1014     Sandra     Onoja   Female  1989-04-12   Delta
# 14         1015      Usman      Buba  Unknown  1992-08-??     Edo
# 15         1016        Efe      Erie     Male  1985-07-01   Abuja
# 16         1017      Peace     Okeke  Unknown  1994/11/23   Lagos
# 17         1018     Bassey   Johnson   Female  1990/05/14  Kaduna
# 18         1019       Tope     Okoro   Female  1995-12-02     Edo
# 19         1020     Lilian    Benson  Unknown  1994/11/23     Edo
#
#                 email   join_date
# 0     user0@mail@mail  2020/03/01
# 1    user1@mail@gmail  2021/02/20
# 2     user2@mail@mail  2020/03/01
# 3    user3@mail@gmail  2021/02/20
# 4      user4@mail.com  2022-??-??
# 5      user5@mail.com  2022-??-??
# 6     user6@mail@mail  2019-11-15
# 7    user7@mail@gmail  2020/03/01
# 8    user8@mail@gmail  2023/05/12
# 9     user9@mail@mail  2019-11-15
# 10    user10@mail.com  2022-??-??
# 11    user11@mail.com  2023/05/12
# 12    user12@mail.com  2022-??-??
# 13    user13@mail.com  2021/02/20
# 14  user14@mail@gmail  2022-??-??
# 15  user15@mail@gmail  2022-??-??
# 16   user16@mail@mail  2021/02/20
# 17   user17@mail@mail  2020/03/01
# 18   user18@mail@mail  2022-??-??
# 19  user19@mail@gmail  2020/03/01

# %% [markdown]
# # Treating dates with inconsistent entries

# %%
customers['join_date']=customers['join_date'].replace(r'[^0-9]', '', regex=True)
customers['join_date']=pd.to_datetime(customers['join_date'], errors='coerce')
customers
# Out:
#     customer_id first_name last_name   gender  dob   state              email  \
# 0          1001       John       Doe   Female  NaN     Edo    user0@mail@mail
# 1          1002       Mary     Obaje  Unknown  NaN   Delta   user1@mail@gmail
# 2          1003    Danladi   Danladi   Female  NaN   Lagos    user2@mail@mail
# 3          1004      Grace       Ade   Female  NaN  Kaduna   user3@mail@gmail
# 4          1005     Chioma     Chuks   Female  NaN   Enugu     user4@mail.com
# 5          1006      Ahmed     Bello     Male  NaN   Lagos     user5@mail.com
# 6          1007       Bola       Ade     Male  NaN     Edo    user6@mail@mail
# 7          1008       Ruth       Ebi     Male  NaN   Delta   user7@mail@gmail
# 8          1009      Tunde     Taiwo  Unknown  NaN   Enugu   user8@mail@gmail
# 9          1010      Ngozi      Okon  Unknown  NaN   Enugu    user9@mail@mail
# 10         1011      Emeka       Eze  Unknown  NaN   Enugu    user10@mail.com
# 11         1012       Kate    Okafor   Female  NaN   Abuja    user11@mail.com
# 12         1013       Femi   Adeyemi  Unknown  NaN  Kaduna    user12@mail.com
# 13         1014     Sandra     Onoja   Female  NaN   Delta    user13@mail.com
# 14         1015      Usman      Buba  Unknown  NaN     Edo  user14@mail@gmail
# 15         1016        Efe      Erie     Male  NaN   Abuja  user15@mail@gmail
# 16         1017      Peace     Okeke  Unknown  NaN   Lagos   user16@mail@mail
# 17         1018     Bassey   Johnson   Female  NaN  Kaduna   user17@mail@mail
# 18         1019       Tope     Okoro   Female  NaN     Edo   user18@mail@mail
# 19         1020     Lilian    Benson  Unknown  NaN     Edo  user19@mail@gmail
#
#     join_date
# 0  2020-03-01
# 1  2021-02-20
# 2  2020-03-01
# 3  2021-02-20
# 4         NaT
# 5         NaT
# 6  2019-11-15
# 7  2020-03-01
# 8  2023-05-12
# 9  2019-11-15
# 10        NaT
# 11 2023-05-12
# 12        NaT
# 13 2021-02-20
# 14        NaT
# 15        NaT
# 16 2021-02-20
# 17 2020-03-01
# 18        NaT
# 19 2020-03-01

# %%
customers.to_csv("clean_customer.csv")
customers.head()
# Out:
#    customer_id first_name last_name   gender  dob   state             email  \
# 0         1001       John       Doe   Female  NaN     Edo   user0@mail@mail
# 1         1002       Mary     Obaje  Unknown  NaN   Delta  user1@mail@gmail
# 2         1003    Danladi   Danladi   Female  NaN   Lagos   user2@mail@mail
# 3         1004      Grace       Ade   Female  NaN  Kaduna  user3@mail@gmail
# 4         1005     Chioma     Chuks   Female  NaN   Enugu    user4@mail.com
#
#    join_date
# 0 2020-03-01
# 1 2021-02-20
# 2 2020-03-01
# 3 2021-02-20
# 4        NaT

# %%
transactions=pd.read_csv("transactions.csv")
transactions.head()
# Out:
#    transaction_id  account_id        date      type amount channel
# 0            3001        2002  2024-01-14   deposit  3000@     POS
# 1            3002        2017  2024-01-14  transfer  ?1500    USSD
# 2            3003        2001  2024-03-05  transfer   2000    USSD
# 3            3004        2008  2024-01-14   deposit  3000@  Mobile
# 4            3005        2020  2024/02/18      dep@  ₦5000     App

# %%
transactions['date']=transactions['date'].replace(r'[^0-9]','',regex=True)
transactions['date']=pd.to_datetime(transactions['date'], errors='coerce')
transactions['type'].value_counts()
# Out:
# type
# withdrawal    9
# deposit       7
# transfer      7
# WITHDRAW      6
# Deposit       6
# dep@          5
# Name: count, dtype: int64

# %%
transactions['type']=transactions['type'].replace(r'WITHDRAW','withdrawal',regex=True)
transactions['type']=transactions['type'].replace(r'Deposit','deposit',regex=True)
transactions['type']=transactions['type'].replace(r'dep@','deposit',regex=True)
transactions['type'].value_counts()
# Out:
# type
# deposit       18
# withdrawal    15
# transfer       7
# Name: count, dtype: int64

# %%
transactions['amount']=transactions['amount'].astype(str).str.replace(r'[^0-9]','',regex=True).astype(float)
transactions.head()
# Out:
#    transaction_id  account_id       date      type     amount channel
# 0            3001        2002 2024-01-14   deposit  3000000.0     POS
# 1            3002        2017 2024-01-14  transfer  1500000.0    USSD
# 2            3003        2001 2024-03-05  transfer  2000000.0    USSD
# 3            3004        2008 2024-01-14   deposit  3000000.0  Mobile
# 4            3005        2020 2024-02-18   deposit  5000000.0     App

# %%
transactions.to_csv("clean_transactions.csv")

# %%
sns.countplot(transactions['type'])
# Out:
# <Axes: xlabel='count', ylabel='type'>

# %%
sns.pairplot(transactions)

# %%
sns.pairplot(transactions, hue='type')

# %%
sns.pairplot(transactions, hue='channel')

# %%
sns.countplot(x='type', hue='channel', data=transactions)

plt.title('Transactions by Type and Channel')
plt.xlabel('Transaction Type')
plt.ylabel('Count')
plt.legend(title='Channel')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[120], line 3
#       1 sns.countplot(x='type', hue='channel', data=transactions)
# ----> 3 plt.title('Transactions by Type and Channel')
#       4 plt.xlabel('Transaction Type')
#       5 plt.ylabel('Count')
#
# File ~\anaconda3\Anaconda\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'title'

# %%
transactions.head()
# Out:
#    transaction_id  account_id       date      type     amount channel
# 0            3001        2002 2024-01-14   deposit  3000000.0     POS
# 1            3002        2017 2024-01-14  transfer  1500000.0    USSD
# 2            3003        2001 2024-03-05  transfer  2000000.0    USSD
# 3            3004        2008 2024-01-14   deposit  3000000.0  Mobile
# 4            3005        2020 2024-02-18   deposit  5000000.0     App

# %%
accounts.head()
# Out:
#    account_id  customer_id account_type  open_date  balance
# 0        2001         1017      current 2020-03-01  70000.0
# 1        2002         1002      current 2021-04-12  40000.0
# 2        2003         1012      savings 2022-06-09  40000.0
# 3        2004         1003      current 2020-03-01  70000.0
# 4        2005         1017      savings 2020-03-01  30000.0

# %%
loan.head()
# Out:
#    loan_id  customer_id issue_date   due_date  principal_amount  \
# 0     4001         1017 2023-09-15 2024-09-15           50000.0
# 1     4002         1014 2023-07-01 2024-07-01           50000.0
# 2     4003         1019 2024-01-10 2024-07-01           50000.0
# 3     4004         1019 2024-01-10 2024-07-01          100000.0
# 4     4005         1003 2024-01-10 2024-07-01           75000.0
#
#    interest_rate   status
# 0           12.0   repaid
# 1           12.0  pending
# 2           12.0   active
# 3           12.0   repaid
# 4           12.0   repaid

# %%
customers.head()
# Out:
#    customer_id first_name last_name   gender  dob   state             email  \
# 0         1001       John       Doe   Female  NaN     Edo   user0@mail@mail
# 1         1002       Mary     Obaje  Unknown  NaN   Delta  user1@mail@gmail
# 2         1003    Danladi   Danladi   Female  NaN   Lagos   user2@mail@mail
# 3         1004      Grace       Ade   Female  NaN  Kaduna  user3@mail@gmail
# 4         1005     Chioma     Chuks   Female  NaN   Enugu    user4@mail.com
#
#    join_date
# 0 2020-03-01
# 1 2021-02-20
# 2 2020-03-01
# 3 2021-02-20
# 4        NaT

# %% [markdown]
# # Machine learning analysis to conduct
# ## Features and Target
# ### Features
# - Gender
# - Age using join date
# - Interest rate
# - Principal amount
# - Duration
# - Account Balance
# ### Target
# - Loan Status
